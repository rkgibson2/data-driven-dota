# %%
# %matplotlib inline

import json

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 30)

# set some nicer defaults for matplotlib
from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecessary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %%
api_key = '7F56AE3AB4357C3E54E73235A0ADE818'

url = "https://api.steampowered.com/IEconDOTA2_570/GetHeroes/v0001/?key=7F56AE3AB4357C3E54E73235A0ADE818&language=en_us"
    
data = requests.get(url).text
data = json.loads(data)  # load a json string into a collection of lists and dicts
data= data.get('result')
data = data.get('heroes')

heroes = [i.get('name') for i in data]
names = [str(i).split("hero_") for i in heroes]
hero_names = [i[1] for i in names]
    
#print hero_names
    
url = "http://cdn.dota2.com/apps/dota2/images/heroes/%s_full.png"
for i in hero_names:
    url = "http://cdn.dota2.com/apps/dota2/images/heroes/%s_full.png" % i
    print url
    
    
import urllib
urllib.urlretrieve('http://cdn.dota2.com/apps/dota2/images/heroes/antimage_full.png', 'antimage.jpg')
# Out:
# http://cdn.dota2.com/apps/dota2/images/heroes/antimage_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/axe_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/bane_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/bloodseeker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/crystal_maiden_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/drow_ranger_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/earthshaker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/juggernaut_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/mirana_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/nevermore_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/morphling_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/phantom_lancer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/puck_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/pudge_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/razor_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/sand_king_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/storm_spirit_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/sven_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/tiny_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/vengefulspirit_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/windrunner_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/zuus_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/kunkka_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/lina_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/lich_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/lion_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/shadow_shaman_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/slardar_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/tidehunter_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/witch_doctor_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/riki_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/enigma_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/tinker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/sniper_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/necrolyte_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/warlock_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/beastmaster_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/queenofpain_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/venomancer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/faceless_void_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/skeleton_king_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/death_prophet_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/phantom_assassin_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/pugna_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/templar_assassin_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/viper_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/luna_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/dragon_knight_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/dazzle_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/rattletrap_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/leshrac_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/furion_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/life_stealer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/dark_seer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/clinkz_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/omniknight_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/enchantress_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/huskar_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/night_stalker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/broodmother_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/bounty_hunter_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/weaver_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/jakiro_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/batrider_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/chen_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/spectre_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/doom_bringer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/ancient_apparition_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/ursa_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/spirit_breaker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/gyrocopter_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/alchemist_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/invoker_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/silencer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/obsidian_destroyer_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/lycan_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/brewmaster_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/shadow_demon_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/lone_druid_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/chaos_knight_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/meepo_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/treant_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/ogre_magi_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/undying_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/rubick_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/disruptor_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/nyx_assassin_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/naga_siren_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/keeper_of_the_light_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/wisp_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/visage_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/slark_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/medusa_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/troll_warlord_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/centaur_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/magnataur_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/shredder_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/bristleback_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/tusk_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/skywrath_mage_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/abaddon_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/elder_titan_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/legion_commander_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/ember_spirit_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/earth_spirit_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/abyssal_underlord_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/terrorblade_full.png
# http://cdn.dota2.com/apps/dota2/images/heroes/phoenix_full.png
# ('antimage.jpg', <httplib.HTTPMessage instance at 0x106a80ab8>)

# %%
requests.get("http://cdn.dota2.com/apps/dota2/images/heroes/antimage_full.png")
# Out:
# <Response [200]>

# %%
api_key = '7F56AE3AB4357C3E54E73235A0ADE818'
account_id = '4294967295'
url = 'https://api.steampowered.com/IDOTA2Match_570/GetMatchHistory/V001/?key=%s&account_id=137890825&start_at_match_id=426961232' % api_key

data = requests.get(url, params=options).text
data = json.loads(data)  # load a json string into a collection of lists and dicts

print json.dumps(data, indent=2)  # dump an object into a json string
# Out:
# {
#   "result": {
#     "status": 1,
#     "total_results": 500,
#     "matches": [
#       {
#         "players": [
#           {
#             "hero_id": 15,
#             "account_id": 137890825,
#             "player_slot": 0
#           },
#           {
#             "hero_id": 74,
#             "account_id": 89235660,
#             "player_slot": 1
#           },
#           {
#             "hero_id": 98,
#             "account_id": 95007477,
#             "player_slot": 2
#           },
#           {
#             "hero_id": 5,
#             "account_id": 125276346,
#             "player_slot": 3
#           },
#           {
#             "hero_id": 35,
#             "account_id": 4294967295,
#             "player_slot": 4
#           },
#           {
#             "hero_id": 20,
#             "account_id": 28095145,
#             "player_slot": 128
#           },
#           {
#             "hero_id": 104,
#             "account_id": 4294967295,
#             "player_slot": 129
#           },
#           {
#             "hero_id": 14,
#             "account_id": 4294967295,
#             "player_slot": 130
#           },
#           {
#             "hero_id": 42,
#             "account_id": 4294967295,
#             "player_slot": 131
#           },
#           {
#             "hero_id": 89,
#             "account_id": 4294967295,
#             "player_slot": 132
#           }
#         ],
#         "start_time": 1387221286,
#         "match_seq_num": 388951389,
#         "match_id": 426961232,
#         "lobby_type": 7
#       },
#       {
#         "players": [
#           {
#             "hero_id": 84,
#             "account_id": 4294967295,
#             "player_slot": 0
#           },
#           {
#             "hero_id": 75,
#             "account_id": 4294967295,
#             "player_slot": 1
#           },
#           {
#             "hero_id": 42,
#             "account_id": 4294967295,
#             "player_slot": 2
#           },
#           {
#             "hero_id": 31,
#             "account_id": 4294967295,
#             "player_slot": 3
#           },
#           {
#             "hero_id": 17,
#             "account_id": 4294967295,
#             "player_slot": 4
#           },
#           {
#             "hero_id": 32,
#             "account_id": 137890825,
#             "player_slot": 128
#           },
#           {
#             "hero_id": 90,
#             "account_id": 4294967295,
#             "player_slot": 129
#           },
#           {
#             "hero_id": 7,
#             "account_id": 4294967295,
#             "player_slot": 130
#           },
#           {
#             "hero_id": 59,
#             "account_id": 4294967295,
#             "player_slot": 131
#           },
#           {
#             "hero_id": 14,
#             "account_id": 4294967295,
#             "player_slot": 132
#           }
#         ],
#         "start_time": 1387216294,
#         "match_seq_num": 388874832,
#         "match_id": 426850435,
#         "lobby_type": 0
#       },
#       {
#         "players": [
#           {
#             "hero_id": 26,
#             "account_id": 4294967295,
#             "player_slot": 0
#           },
#           {
#             "hero_id": 56,
#             "account_id": 4294967295,
#             "player_slot": 1
#           },
#           {
#             "hero_id": 96,
#             "account_id": 4294967295,
#             "player_slot": 2
#           },
#           {
#             "hero_id": 6,
#             "account_id": 4294967295,
#             "player_slot": 3
#           },
#           {
#             "hero_id": 41,
#             "account_id": 4294967295,
#             "player_slot": 4
#           },
#           {
#             "hero_id": 99,
#             "account_id": 137890825,
#             "player_slot": 128
#           },
#           {
#             "hero_id": 9,
#             "account_id": 4294967295,
#             "player_slot": 129
#           },
#           {
#             "hero_id": 53,
#             "account_id": 4294967295,
#             "player_slot": 130
#           },
#           {
#             "hero_id": 82,
#             "account_id": 101913102,
#             "player_slot": 131
#           },
#           {
#             "hero_id": 73,
#             "account_id": 4294967295,
#             "player_slot": 132
#           }
#         ],
#         "start_time": 1387212005,
#         "match_seq_num": 388782889,
#         "match_id": 426742400,
#         "lobby_type": 0
#       },
#       {
#         "players": [
#           {
#             "hero_id": 46,
#             "account_id": 4294967295,
#             "player_slot": 0
#           },
#           {
#             "hero_id": 104,
#             "account_id": 4294967295,
#             "player_slot": 1
#           },
#           {
#             "hero_id": 44,
#             "account_id": 4294967295,
#             "player_slot": 2
#           },
#           {
#             "hero_id": 39,
#             "account_id": 4294967295,
#             "player_slot": 3
#           },
#           {
#             "hero_id": 99,
#             "account_id": 4294967295,
#             "player_slot": 4
#           },
#           {
#             "hero_id": 70,
#             "account_id": 95650876,
#             "player_slot": 128
#           },
#           {
#             "hero_id": 32,
#             "account_id": 137890825,
#             "player_slot": 129
#           },
#           {
#             "hero_id": 62,
#             "account_id": 4294967295,
#             "player_slot": 130
#           },
#           {
#             "hero_id": 89,
#             "account_id": 4294967295,
#             "player_slot": 131
#           },
#           {
#             "hero_id": 51,
#             "account_id": 4294967295,
#             "player_slot": 132
#           }
#         ],
#         "start_time": 1387208756,
#         "match_seq_num": 388677318,
#         "match_id": 426657991,
#         "lobby_type": 0
#       },
#       {
#         "players": [
#           {
#             "hero_id": 62,
#             "account_id": 144497366,
#             "player_slot": 0
#           },
#           {
#             "hero_id": 51,
#             "account_id": 4294967295,
#             "player_slot": 1
#           },
#           {
#             "hero_id": 44,
#             "account_id": 4294967295,
#             "player_slot": 2
#           },
#           {
#             "hero_id": 80,
#             "account_id": 4294967295,
#             "player_slot": 3
#           },
#           {
#             "hero_id": 21,
#             "account_id": 4294967295,
#             "player_slot": 4
#           },
#           {
#             "hero_id": 32,
#             "account_id": 137890825,
#             "player_slot": 128
#           },
#           {
#             "hero_id": 14,
#             "account_id": 4294967295,
#             "player_slot": 129
#           },
#           {
#             "hero_id": 64,
#             "account_id": 4294967295,
#             "player_slot": 130
#           },
#           {
#             "hero_id": 94,
#             "account_id": 101934425,
#             "player_slot": 131
#           },
#           {
#             "hero_id": 1,
#             "account_id": 4294967295,
#             "player_slot": 132
#           }
#         ],
#         "start_time": 1387204777,
#         "match_seq_num": 388605487,
#         "match_id": 426550215,
#         "lobby_type": 0
#       }
#     ],
#     "num_results": 5,
#     "results_remaining": 0
#   }
# }

# %%
#call get match history for all given matches
#we need to call until results_remaining = 0

#then call get match details 

#

# %%
account_id = '137890825'

def fetch_match_history(account_id): 
    
    #we can call the API six times and we'll grab all available data from the API
    #if account id = 4294967295
    
    #first API call
    url = 'https://api.steampowered.com/IDOTA2Match_570/GetMatchHistory/V001/?key=7F56AE3AB4357C3E54E73235A0ADE818&date_max&account_id=' + account_id
    data = requests.get(url).text
    data = json.loads(data)
    
    df = pd.DataFrame.from_dict(data)    
    
    return df

fetch_match_history(account_id)
# Out:
#                                                               result
# matches            [{u'players': [{u'hero_id': 51, u'account_id':...
# num_results                                                      100
# results_remaining                                                400
# status                                                             1
# total_results                                                    500
